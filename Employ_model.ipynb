# %%
import torch
import Train_letter_model as llm
import Train_BPE_model as bpellm
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
device = torch.device("cpu")

# Load checkpoint
checkpoint = torch.load(
    "tiny_transformer_bpe.pt",
    map_location="cpu",
    weights_only=True,
)

config = checkpoint["config"]

# Set the globals used by your model classes
bpellm.vocab_size = config["vocab_size"]
bpellm.block_size = config["block_size"]
bpellm.n_embd = config["n_embd"]
bpellm.n_head = config["n_head"]
bpellm.n_layer = config["n_layer"]
bpellm.dropout = config["dropout"]

# Reconstruct model
model = bpellm.Tiny_GPT()

model.load_state_dict(
    checkpoint["model_state_dict"]
)

model.to(device)
model.eval()

# Load the matching tokenizer
tokenizer = Tokenizer.from_file(
    checkpoint["tokenizer_path"]
)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
prompt = "Once upon a time there was a dragon"

prompt_ids = tokenizer.encode(prompt).ids

input_tokens = torch.tensor(
    [prompt_ids],
    dtype=torch.long,
    device=device,
)

with torch.no_grad():
    generated = model.generate(
        input_tokens,
        max_new_tokens=300,
    )

generated_text = tokenizer.decode(
    generated[0].tolist()
)

print(generated_text)
# Out:
# Once upon a time there was a dragon. This place wanted to ride the job. So, the moon got all alone. They played together all day and felt very sad.
# But when it was time to go home, the witch found a new one. Seeedy was scared because the big red truck was wealthy. It was very dry and having fun. It went away with its family again and everyone couldn't measure it. But the little boy disappear did not want them anywhere and quickly ran away.
# Then, something unexpected happened. It made her foot! The boy and the brave boy were surprised, but they couldn't have any their time to go home. They measured the bucket in its mouth and went inside. The boy laughed and played with the buckle all day.
# <|endoftext|>
# One day, a cat and a dog were playing on a tree. The cat had a car that could not move. The cat wanted to shake the printbuard or winner. The car wanted to march too. So, the cat ran away and got out of the slide.
# The cat tried again and again, but they were not scared. But this time, the cat could not move away. The cat did not go away. The cat climbed.
# The cat and Tom both

# %%
prompt = "Tim wanted to"

prompt_ids = tokenizer.encode(prompt).ids

input_tokens = torch.tensor(
    [prompt_ids],
    dtype=torch.long,
    device=device,
)

generated = model.generate(
        input_tokens,
        max_new_tokens=300,
    )

generated_text = tokenizer.decode(
    generated[0].tolist()
)

print(generated_text)
# Out:
# Tim wanted to make the food very much. But all his friends stopped spoiled for him. They all shared the yummy food and were very happy.
# The moral of the story is that sharing with others can still have fun, even when things don't need she found if you need more things to create in it. Just then, they kept grumpy to be patient. Just believed as the leather first ping up so he showed Jessicaws something special. People kept it safe! At the end of the day, Jane never forgular off home before.
# <|endoftext|>
# Once upon a time, there was a big stubborn little dog named Spot. Spot was very intelligent. He liked to play on the street darkly things to run, jump, show them how high he was.
# One sunny day, Spot saw a big planet in the tree. He wanted to help where he found it. What came across him's head and said, "Can I go there, please?"
# Anna and Max saw the planet and wanted to eat it. They asked Tom, "Can we ride the same cheese?"
# Tom and his mom tried their way away the sleddom, but they didn't care
